# %% [markdown]
# <a href="https://colab.research.google.com/github/makhmudov-khondamir/Machine-Learning-Projects/blob/main/Sanoat_fan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('/content/Ishlab chiqarish sanoati tarkibida tumanlarning ulushi.xlsx')
df.head()
# Out:
#   2024 yil yanvar-iyun oylarida Toshkent shahrida ishlab chiqarish sanoati tarkibida tumanlarning ulushi, %  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                         Ishlab chiqaradigan sanoat
# 4          Oziq- ovqat mahsulotlari ishlab chiqarish
#
#         Unnamed: 1      Unnamed: 2       Unnamed: 3        Unnamed: 4  \
# 0              NaN             NaN              NaN               NaN
# 1              NaN             NaN              NaN               NaN
# 2  Toshkent shahri  Uchtepa tumani  Bektemir tumani  Yunusobod tumani
# 3              100             100              100               100
# 4        12.956629       18.167477         6.358441         21.852547
#
#               Unnamed: 5      Unnamed: 6           Unnamed: 7      Unnamed: 8  \
# 0                    NaN             NaN                  NaN             NaN
# ...

# %%
tosh=df[3:]
mirobod=tosh[['2024 yil yanvar-iyun oylarida Toshkent shahrida ishlab chiqarish sanoati tarkibida tumanlarning ulushi, %','Unnamed: 6']][1:]

# %%
mirobod=mirobod[:-1]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=mirobod.sort_values(by=['Unnamed: 6'],ascending=0)[:9]

# %%
data
# Out:
#    2024 yil yanvar-iyun oylarida Toshkent shahrida ishlab chiqarish sanoati tarkibida tumanlarning ulushi, %  \
# 21                  elektr uskunalar ishlab chiqarish
# 27     Mashina va uskunalarni ta`mirlash va o`rnatish
# 6                Tamaki mahsulotlari ishlab chiqarish
# 20  Kompyuterlar, elektron va optik mahsulotlar is...
# 17  Boshqa nometall mineral mahsulotlar ishlab chi...
# 4           Oziq- ovqat mahsulotlari ishlab chiqarish
# 16     Rezina va plastmassa buyumlar ishlab chiqarish
# 11     Qog`oz va qog`oz mahsulotlari ishlab chiqarish
# 18                               Metallurgiya sanoati
#
#    Unnamed: 6
# 21  30.655839
# 27  13.881783
# 6    13.11802
# 20   7.084535
# 17   6.757347
# 4    5.761662
# 16   5.481829
# 11   4.039977
# 18   3.310399

# %%
import seaborn as sns
import matplotlib.pyplot as plt

colors = sns.color_palette('pastel')[0:5]
label=data['2024 yil yanvar-iyun oylarida Toshkent shahrida ishlab chiqarish sanoati tarkibida tumanlarning ulushi, %'].values
plt.figure(figsize=[8,6])
plt.pie(data['Unnamed: 6'], labels=label,colors=colors, autopct='%1.1f%%', startangle=140,rotatelabels=False)

# Add title
plt.title('2024 yil yanvar-iyun oylarida Toshkent shahrida ishlab chiqarish sanoati tarkibida tumanlarning ulushi, %')

# Show the plot
plt.show()

# %% [markdown]
#  Doiraviy diagrammada Toshkent shahrida Mirobod tumanining 2024 yilning yanvaridan iyunigacha bo‘lgan sanoat ishlab chiqarishining taqsimoti ko‘rsatilgan.
#
#  Asosiy fikrlar:
#  1. Elektr jihozlarini ishlab chiqarish 34% ni tashkil qiladi.
#  2. Mashinalarni ta'mirlash (15,4%) va tamaki mahsulotlari (14,6%) keyingi yirik tarmoqlardir.
#  3. Keyingi o'rinlarda kompyuter va elektron mahsulotlar (7,9%) va metall bo'lmagan mineral mahsulotlar (7,5%).
#  4. Bir necha kichikroq sektorlar, jumladan, oziq-ovqat mahsulotlari va kauchuk/plastmassa, har biri 6% yoki undan kamroq hissa qo'shadi.
#
#  Umuman olganda, Mirobod sanoatida elektrotexnika asbob-uskunalari ishlab chiqarish yetakchilik qiladi, bunda mashinasozlik va tamaki sanoatining hissasi katta.  Qolgan tarmoqlar umumiy ishlab chiqarishning xilma-xil, ammo kichikroq qismini tashkil qiladi

# %%
import plotly.graph_objects as go
import pandas as pd

pastel_colors = ['rgb(255, 179, 186)', 'rgb(255, 223, 186)', 'rgb(255, 255, 186)',
                 'rgb(186, 255, 201)', 'rgb(186, 225, 255)']

fig = go.Figure(data=[go.Pie(
    labels=data['2024 yil yanvar-iyun oylarida Toshkent shahrida ishlab chiqarish sanoati tarkibida tumanlarning ulushi, %'],
    values=data['Unnamed: 6'],
    textinfo='label+percent',
    insidetextorientation='radial',
    hoverinfo='label+percent+value',
    marker=dict(colors=pastel_colors)
)])

fig.update_layout(
    title='2024 yil yanvar-iyun oylarida Toshkent shahrida ishlab chiqarish sanoati tarkibida tumanlarning ulushi, %',
    height=600,
    width=800
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head(3)
# Out:
#   2024 yil yanvar-iyun oylarida Toshkent shahrida ishlab chiqarish sanoati tarkibida tumanlarning ulushi, %  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#         Unnamed: 1      Unnamed: 2       Unnamed: 3        Unnamed: 4  \
# 0              NaN             NaN              NaN               NaN
# 1              NaN             NaN              NaN               NaN
# 2  Toshkent shahri  Uchtepa tumani  Bektemir tumani  Yunusobod tumani
#
#               Unnamed: 5      Unnamed: 6           Unnamed: 7      Unnamed: 8  \
# 0                    NaN             NaN                  NaN             NaN
# 1                    NaN             NaN                  NaN             NaN
# 2  Mirzo Ulug'bek tumani  Mirobod tumani  Shayhontoxur tumani  Olmazor tumani
#
#        Unnamed: 9        Unnamed: 10       Unnamed: 11       Unnamed: 12  \
# ...

# %%
col=df.iloc[2]. values

# %%
df1=df[4:]
df1.columns=col
df1
# Out:
#                                                   NaN Toshkent shahri  \
# 4           Oziq- ovqat mahsulotlari ishlab chiqarish       12.956629
# 5                        Ichimliklar ishlab chiqarish       10.145863
# 6                Tamaki mahsulotlari ishlab chiqarish        0.731764
# 7         To`qimachilik mahsulotlari ishlab chiqarish        4.536383
# 8                              Kiyim ishlab chiqarish        2.149873
# 9   Teri va unga tegishli mahsulotlar ishlab chiqa...        0.170099
# 10  Yog`och va po`kak buyumlar (mebeldan tashqari)...        0.782933
# 11     Qog`oz va qog`oz mahsulotlari ishlab chiqarish        2.793895
# 12  Yozilgan materiallarni nashr qilish va aks ett...        1.600296
# 13  Koks va neftni qayta ishlash mahsulotlari ishl...        0.407624
# 14                Kimyo mahsulotlari ishlab chiqarish        3.183314
# 15  Asosiy farmatsevtika mahsulotlari va preparatl...        2.553179
# ...

# %%
df1.head()
# Out:
#                                            NaN Toshkent shahri Uchtepa tumani  \
# 4    Oziq- ovqat mahsulotlari ishlab chiqarish       12.956629      18.167477
# 5                 Ichimliklar ishlab chiqarish       10.145863       0.856643
# 6         Tamaki mahsulotlari ishlab chiqarish        0.731764              0
# 7  To`qimachilik mahsulotlari ishlab chiqarish        4.536383       1.313224
# 8                       Kiyim ishlab chiqarish        2.149873       1.637402
#
#   Bektemir tumani Yunusobod tumani Mirzo Ulug'bek tumani Mirobod tumani  \
# 4        6.358441        21.852547              6.194236       5.761662
# 5       45.751127         2.921922              0.532009       0.384208
# 6               0                0                     0       13.11802
# 7        2.541339         1.458252                1.6574       1.091594
# 8        0.210859         2.681234              1.391688       0.893264
#
# ...

# %%
df1.set_index(np.nan,inplace=True)
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-73f8f2a3f0b0> in <cell line: 1>()
# ----> 1 df1.set_index(np.nan,inplace=True)
#       2 df1
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5868
#    5869         if missing:
# -> 5870             raise KeyError(f"None of {missing} are in the columns")
#    5871
#    5872         if inplace:
#
# KeyError: 'None of [nan] are in the columns'

# %%
df2=df1.transpose()

# %%
df2.head(2)
# Out:
# nan             Oziq- ovqat mahsulotlari ishlab chiqarish  \
# Toshkent shahri                                 12.956629
# Uchtepa tumani                                  18.167477
#
# nan             Ichimliklar ishlab chiqarish  \
# Toshkent shahri                    10.145863
# Uchtepa tumani                      0.856643
#
# nan             Tamaki mahsulotlari ishlab chiqarish  \
# Toshkent shahri                             0.731764
# Uchtepa tumani                                     0
#
# nan             To`qimachilik mahsulotlari ishlab chiqarish  \
# Toshkent shahri                                    4.536383
# Uchtepa tumani                                     1.313224
#
# nan             Kiyim ishlab chiqarish  \
# Toshkent shahri               2.149873
# Uchtepa tumani                1.637402
#
# nan             Teri va unga tegishli mahsulotlar ishlab chiqarish  \
# Toshkent shahri                                           0.170099
# ...

# %%
import pandas as pd
import numpy as np


print("Actual column names in the DataFrame:")
print(df2.columns.tolist())

column_sums = df2.sum()

sorted_columns = column_sums.sort_values(ascending=False)
top_5_columns = sorted_columns.head(5).index.tolist()

print("\nTop 5 columns based on sum:")
print(top_5_columns)

top_5_data = df2[top_5_columns]

print("\nDataFrame with Top 5 Indicators:")
print(top_5_data)
print("\nSums of Top 5 Indicators:")
df3=column_sums[top_5_columns]
# Out:
# Actual column names in the DataFrame:
# ...

# %%
plt.plot(figure=[10,8])
sns.barplot(x=df3.index, y=df3.values)
plt.xticks(rotation=90)
plt.title("Tumanlar ichida top 5ta sanoat tarmogi")
plt.show()

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[
    go.Bar(x=df3.index, y=df3.values)
])

fig.update_layout(
    title="Tumanlar ichida top 5ta sanoat tarmogi",
    xaxis_title="Tumanlar",
    yaxis_title="Qiymat",
    height=600,
    width=1000
)

fig.update_xaxes(tickangle=90)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sanoat=pd.read_excel("/content/Sanoat ishlab chiqarish hajmida tumanlar ulushi.xlsx")

# %%
sanoat=sanoat[2:]
sanoat
# Out:
#    Shahar bo`yicha jami sanoat ishlab chiqarish hajmida tumanlar ulushi  \
# 2                                                 NaN
# 3                                     Toshkent shahar
# 4                                           tumanlar:
# 5                                             Uchtepa
# 6                                            Bektemir
# 7                                           Yunusobod
# 8                                      Mirzo-Ulug`bek
# 9                                             Mirobod
# 10                                       Shayxontoxur
# 11                                            Olmazor
# 12                                            Sergeli
# 13                                         Yakkasaroy
# 14                                          Yashnobod
# 15                                         Yangihayot
# 16                                          Chilonzor
# 17                                                NaN
# ...

# %%
column=sanoat.iloc[0]. values

# %%
values=sanoat.iloc[7].values

# %%
mirobod_sanoat=pd.DataFrame(values, index=column)

# %%
mirobod_sanoat=mirobod_sanoat[1:]

# %%
mirobod_sanoat.columns=['values']

# %%
mirobod_sanoat
# Out:
#                                                      values
# 2010 yil                                           8.400149
# 2011 yil                                           7.214739
# 2012 yil                                            7.02758
# 2013 yil                                           6.691005
# 2014 yil                                           8.017155
# 2015 yil                                           8.196729
# 2016 yil                                           7.622828
# 2017 yil                                           9.230953
# 2018 yil                                           9.846202
# 2019 yil                                          16.110664
# 2020 yil                                           9.166952
# 2021 yil                                           8.944471
# 2022 yil                                                7.4
# 2023-yil                                           6.370239
# *2024-yil                            yanvar-iyun   6.150705

# %%
mirobod_sanoat=mirobod_sanoat.astype(float)

# %%
plt.figure(figsize=[10,8])
plt.plot(mirobod_sanoat.index, mirobod_sanoat.values)
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# Chiziqli grafik 2010 yildan 2024 yilgacha bo'lgan sanoat ishlab chiqarish hajmida Mirobod tumanining ulushining trendi berilgan. Qiymatlar foiz o'zgarishlarini ko'rsatadi.
#
#  2010 yildan 2012 yilgacha foizlar biroz pasayib, 2010 yildagi 8,40% dan 2012 yilda 7,03% gacha pasaygan. Ushbu pasayish tendentsiyasi 2013 yilgacha davom etib, bunda qiymat yana 6,69% gacha kamayadi.  Biroq, 2014 yildan boshlab, qiymatlar ko'tarilib, 2017 yilda 9,23% gacha bo'lgan tiklanish kuzatilmoqda.
#
#  2019 yilda 16,11 foizga sezilarli o'sish kuzatildi, bu davr mobaynida qayd etilgan eng yuqori ko'rsatkichdir.  Biroq, bu 2020 yilda 9,17% gacha keskin pasayish bilan kuzatiladi.  Foizlar 2021 yildan boshlab asta-sekin pasayishda davom etmoqda va 2024 yilning birinchi yarmida 6,15% ga yetdi.
#
#  Xulosa qilib aytganda, ma'lumotlar o'zgaruvchan trendni ko'rsatadi, 2019 yilda sezilarli o'sish, so'ngra so'nggi yillarda asta-sekin pasayish kuzatilgan.

# %%
sns.heatmap(data=mirobod_sanoat)
# Out:
# <Axes: >
